# %%
import requests
from dotenv import load_dotenv
import os
import pandas as pd
load_dotenv('../envs/dev.env')

token = os.getenv("HCDP_ADMIN_TOKEN")

headers = {
    "Authorization": f"Bearer {token}"
}


# body = {
#     "email": "cherryle@hawaii.edu",
#     "island": ["Statewide"],
#     # "moku": ["Kauaʻi::wahiawa"]
# }

# %%
# #subscribe
# url = "https://api.hcdp.ikewai.org/mesonet/climate_report/subscribe"
# res = requests.post(url, json = body, headers = headers)
# res.raise_for_status()
# print("User subscribed")
# Out:
# User subscribed

# %%
#View all subscriptions

url = "https://api.hcdp.ikewai.org/mesonet/climate_report/subscriptions"

res = requests.get(url, headers=headers)
res.raise_for_status()

subscriptions = res.json()

df = pd.DataFrame(subscriptions)
for col in ['ahupuaa', 'island', 'watershed', 'moku', 'climate']:
    df[col] = df[col].apply(lambda x: ', '.join(x) if x else '')
df
# Out:
#                                        id  \
# 0    acc68a07-c5bc-4a0d-b2b1-2ffd40b210d0
# 1    e900753f-8922-46ab-9064-6438de84446c
# 2    98f9c789-5ac5-427c-9ad8-e1f9076e8b3c
# 3    b97d6c05-82ca-4368-92b2-2c52e0719f12
# 4    60ebba28-21ba-4f67-baf5-986ce1215eb4
# ..                                    ...
# 293  36f56c92-0fa5-4604-b290-348041a01010
# 294  86efcd11-5d87-4e2b-bf61-84a403935d85
# 295  ed642165-433c-4177-a047-0f689ce8e477
# 296  051ed78c-68c7-427c-8a3b-0c004c95359d
# 297  3a61f5d7-9133-416b-9e43-dfb367ba8a4f
#
#                                    email                  ahupuaa  \
# 0                  citydesk@mauinews.com
# 1                 cherrylee983@gmail.com          Oʻahu::Maunalua
# 2                    cherryle@hawaii.edu          Oʻahu::Maunalua
# 3                    smiyazono@gmail.com
# 4                        colo@hawaii.edu  Hawaiʻi::Waikahekahenui
# ..                                   ...                      ...
# 293  frozen_coastland875@simplelogin.com
# 294                   mohalap@hawaii.edu       Hawaiʻi::Piʻihonua
# 295                     mzell@hawaii.edu           Oʻahu::Waikīkī
# 296                    dsahin@hawaii.edu
# 297          tova.a.callender@hawaii.gov
#
#                                 island            watershed           moku  \
# 0    Maui, Lānaʻi, Molokaʻi, Statewide
# 1                     Oʻahu, Statewide
# 2                     Oʻahu, Statewide  Hawaiʻi::Koholālele
# 3                     Oʻahu, Statewide
# 4                   Hawaiʻi, Statewide                       Hawaiʻi::Puna
# ..                                 ...                  ...            ...
# 293                          Statewide
# 294                 Hawaiʻi, Statewide
# 295                   Oʻahu, Statewide
# 296                          Statewide
# 297                    Maui, Statewide        Maui::Waiakoa
#
#     climate
# 0
# 1
# 2
# 3
# 4
# ..      ...
# 293
# 294
# 295
# 296
# 297
#
# [298 rows x 7 columns]

# %%
res.json()
# Out:
# [{'id': 'acc68a07-c5bc-4a0d-b2b1-2ffd40b210d0',
#   'email': 'citydesk@mauinews.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Lānaʻi', 'Molokaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e900753f-8922-46ab-9064-6438de84446c',
#   'email': 'cherrylee983@gmail.com',
#   'ahupuaa': ['Oʻahu::Maunalua'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '98f9c789-5ac5-427c-9ad8-e1f9076e8b3c',
#   'email': 'cherryle@hawaii.edu',
#   'ahupuaa': ['Oʻahu::Maunalua'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Hawaiʻi::Koholālele'],
#   'moku': [],
#   'climate': []},
#  {'id': 'b97d6c05-82ca-4368-92b2-2c52e0719f12',
#   'email': 'smiyazono@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '60ebba28-21ba-4f67-baf5-986ce1215eb4',
#   'email': 'colo@hawaii.edu',
#   'ahupuaa': ['Hawaiʻi::Waikahekahenui'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': ['Hawaiʻi::Puna'],
#   'climate': []},
#  {'id': 'c5392660-b100-4810-a105-e141744015ab',
#   'email': 'brandon.bukunt@noaa.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '43746295-a9b5-4d53-aa28-cf3fc9600e7a',
#   'email': 'dorothy.j.booth@hawaii.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '490b87c2-2835-4bee-b2f2-444a368347f8',
#   'email': 'jill.ficke-beaton@usda.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'f810a50f-82ab-4dde-8d41-2232fb36d240',
#   'email': 'aamcguig@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '016685c9-d39e-4d2d-9783-2f73c6b328d5',
#   'email': 'rlongman@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Wailoa'],
#   'moku': [],
#   'climate': []},
#  {'id': 'd7620d60-53aa-48d7-a3d0-47e76db9d468',
#   'email': 'djford@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Kaloi'],
#   'moku': [],
#   'climate': []},
#  {'id': 'acc70452-5237-4c72-be7b-b552a2454fc2',
#   'email': 'cherryle.heu@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '90ebe680-efd8-4b64-a4e4-7f8061d99f37',
#   'email': 'mcleanj@hawaii.edu',
#   'ahupuaa': ['Hawaiʻi::Keaʻau'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ee19eef9-29ce-49ad-b0d6-0f164682d9e6',
#   'email': 'thornem@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Maui',
#    'Lānaʻi',
#    'Molokaʻi',
#    'Oʻahu',
#    'Kauaʻi',
#    'Hawaiʻi',
#    'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': ['Hawaiʻi::Windward Kohala',
#    'Hawaiʻi::Leeward Kohala',
#    'Hawaiʻi::Kona',
#    'Hawaiʻi::Kaʻu',
#    'Hawaiʻi::Hilo',
#    'Hawaiʻi::Hawaiʻi Mauka']},
#  {'id': '8e31a233-e31a-4359-850d-6f9f1eae4d92',
#   'email': 'thomas@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5a48288f-f179-4acd-af78-058cc0505d52',
#   'email': 'vmhyomai@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '2a7f3c6d-79b6-41d2-8d8f-66b46217fd8d',
#   'email': 'ealenz@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Heʻeia'],
#   'moku': [],
#   'climate': []},
#  {'id': '90c9783e-2870-4ab9-b617-8eee13065441',
#   'email': 'swoofter@berkeley.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'aadb057d-f9aa-44d1-8415-6e048e204698',
#   'email': 'cherrryle@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'bb0a4eac-e730-4509-ae31-0abfcbe6af6b',
#   'email': 'abbyf@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ec16df5b-f703-4098-9bca-fdd3f0ea3c06',
#   'email': 'kodamak8@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Oʻahu', 'Statewide'],
#   'watershed': ['Hawaiʻi::Hakalau', 'Oʻahu::Nuʻuanu'],
#   'moku': [],
#   'climate': []},
#  {'id': '60bd2236-2880-445f-8ce7-7e1b5f22d796',
#   'email': 'kanesa@hawaii.edu',
#   'ahupuaa': ['Kauaʻi::Keālia'],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '96ad0684-d2ed-45d0-b71e-aff98d38e195',
#   'email': 'akuegler@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'dc982fae-ca29-43be-9b06-e01a4c362f8a',
#   'email': 'ksanfili@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'd939a855-a39d-4658-abb1-d0183864b1dc',
#   'email': 'lknapman@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4a781750-ab60-4096-ac4c-975e48f525b3',
#   'email': 'hendrixs@hawaii.edu',
#   'ahupuaa': ['Oʻahu::Honolulu'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'f4e54b67-2b10-4a15-812b-efe870cf041d',
#   'email': 'hcdp@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Kiikii'],
#   'moku': ['Oʻahu::Koʻolaupoko'],
#   'climate': []},
#  {'id': '3110305b-9ce2-4019-8eee-119a9b442320',
#   'email': 'jill.f.beaton@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '26cba191-e8f4-4066-8bd6-85aea4792470',
#   'email': 'brian.brettschneider@noaa.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5a798246-599c-43de-8f0b-2c7da8a967b6',
#   'email': 'amanda.sheffield@noaa.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a5a169ae-ba9b-45ba-9a65-b25137f97a29',
#   'email': 'puuwairanch@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e6f5b351-4167-4f76-b137-11476f780143',
#   'email': 'erickathielee@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '1fd31903-c100-49ed-b2a5-a415e626531c',
#   'email': 'elizabeth.dykstra@hawaiicounty.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '091b824c-dc82-4e67-bd50-1346b360ec6e',
#   'email': 'laura.acasio@hawaiicounty.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '9fe550f9-e9c9-4f62-80f4-d6c97329993e',
#   'email': 'dylan.young@hawaiicounty.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '10407b1c-9c47-497c-a870-885bcbfd7cc4',
#   'email': 'david@hawaii.edu',
#   'ahupuaa': ['Oʻahu::Waikīkī'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ce9bfabc-eac6-4223-bbcf-f73df4163823',
#   'email': 'joeyoungwx@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '9e1329da-7753-470f-867f-cdd66cae0d43',
#   'email': 'criganti2@unl.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '85bc533a-eb9b-48df-9b98-d878c87067a1',
#   'email': 'nellalegne@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '75c3eabf-8218-42c6-9ea0-988ce077679c',
#   'email': 'bmathews@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '6e40b712-93ae-402b-9d21-a38e0adeadf7',
#   'email': 'hellyj@ucsd.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'fe0d75fe-896e-4c35-ad30-8e2028d72e8e',
#   'email': 'susan.cordell@usda.gov',
#   'ahupuaa': ['Hawaiʻi::Laupāhoehoe, Welokā',
#    'Hawaiʻi::Waiākea',
#    'Hawaiʻi::Puʻuanahulu',
#    'Hawaiʻi::Puʻuwaʻawaʻa'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4135e8a7-7939-42e4-b999-ab6cdf7a14e6',
#   'email': 'jjh@hellylab.net',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '188d6f71-1abd-4b51-a496-529cca3fc7d4',
#   'email': 'cmgrandinetti@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '18008c8c-c728-4945-8ae8-1e90599879d4',
#   'email': 'nconroy@honolulu.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '3a61f5d7-9133-416b-9e43-dfb367ba8a4f',
#   'email': 'tova.a.callender@hawaii.gov',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5cb314bc-7fc1-4ffd-b8d1-2373039b19f3',
#   'email': 'sierra_Mcdaniel@nps.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '74c511da-c9d5-4608-95fd-e80ea27508cc',
#   'email': 'sburr@aecos.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5e47a4ff-ca3e-4555-a834-0fe14f4aca58',
#   'email': 'zz.s.riela@leidos.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8b070bd1-c891-4005-a120-a5becf249753',
#   'email': 'woo.k@pri-hi.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '9771ce46-71a2-49d8-9839-8d2d36e28d34',
#   'email': 'sean.p.miller@noaa.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4d11a75a-f350-412a-97a7-1460ff772196',
#   'email': 'richard.ogoshi@usda.gov',
#   'ahupuaa': [],
#   'island': ['Molokaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '004b8b0c-83ab-483a-b66c-64e4517619c2',
#   'email': 'terrawattblake@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'df861564-6f0d-4fcf-83f9-a6c7e172cca1',
#   'email': 'jfayau@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '182e0b22-922f-4185-aaa6-caaa3255268e',
#   'email': 'kealoha.fox@honolulu.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '6b11f0b6-1ba4-4890-b4f5-a27d6cea5b64',
#   'email': 'alexander.yee@honolulu.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'cae59382-c96a-4377-9b6d-0b4e3920ecda',
#   'email': 'alohamaui@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '33abbbea-1d52-4f3b-9fa8-684ec2fbb1c4',
#   'email': 'mattison.priest@honolulu.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '7ebb33c1-8c63-41c5-92c2-3ed5f4598b3d',
#   'email': 'mattison.priest@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ac7defd4-35e4-474d-b2dc-20b9431ceb22',
#   'email': 'kuyehara@hawaiidws.org',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '46a13962-4590-48f7-90bb-9335041e0876',
#   'email': 'ona.melvin@colorado.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5f850c02-96c8-4e7f-a75f-fa441bcab919',
#   'email': 'mattlasecki@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a81548ac-a8cd-433e-88db-cc8a8935eacd',
#   'email': 'matthew.lasecki@amwater.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e84ffe80-bfb1-461c-baa8-2359a23687ed',
#   'email': 'chimera@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e63fbf41-781f-45cc-adfa-26fba8b123c0',
#   'email': 'fletcher@soest.hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '6cfbc9df-ecde-46b1-b30c-eebf49524626',
#   'email': 'jennifer.johnston@usda.gov',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5ff0d99d-fe49-4b61-a398-4b95172485b9',
#   'email': 'christop.pascua@honolulu.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '49769a6b-2a67-49f1-b8c5-55ceb96295c5',
#   'email': 'km@urmaui.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '44586464-c006-4373-b479-7ed6cd3b8665',
#   'email': 'hector@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '055e9f4a-1cf3-4cf9-8571-8b7790314c3b',
#   'email': 'geosupergeek@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'b336eb67-ab6a-4660-9bf4-55e430c512b6',
#   'email': 'karensyl@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '3ff17a74-c11a-4a27-997e-2b076e7121fd',
#   'email': 'kkonicek@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e2fbb369-c5ff-42c1-a3f7-e5d57d5e721c',
#   'email': 'ppowell@waimeavalley.net',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8af9453a-2151-4f69-99ac-25372905cc42',
#   'email': 'mseifert9@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '9bc9ad62-e734-4424-a5d1-ffa972e6f0eb',
#   'email': 'jonathan.s.simonds@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Kaiwiki, Maumau'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': ['Hawaiʻi::Hilo']},
#  {'id': '0d1399c2-7a6e-4993-84b3-205168a014d9',
#   'email': 'dlung0@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ed970de5-db9e-4937-b2c0-f4ffeb9ae86a',
#   'email': 'coffeebobk@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a6f8a8ad-5705-4fb1-a424-da07a19db2f8',
#   'email': 'zhiwei.zhang@rainhail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4e00ecd9-5b66-4045-87c2-c15829ccf68f',
#   'email': 'pema.hegan@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'f6f4258b-f50f-4ea2-b1a3-f154fc6ddca0',
#   'email': 'cattell@aecos.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c31a9a91-8d3e-4a24-b42e-30acfc73ccb4',
#   'email': 'bbue@mtaonline.net',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '10f31fd8-f8e6-49f7-9056-7471c188a425',
#   'email': 'kristen.kiriu@usda.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '867bb4b7-32c7-4758-8736-0f62c7ce8949',
#   'email': 'robin.beebee@hdrinc.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '0ff0418b-a7fe-4602-bbc1-598d76c853d2',
#   'email': 'Brad.Rippey@usda.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '313cfa4c-986b-45e6-9624-19aa8c954aec',
#   'email': 'dmair@usgs.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'bf9d261a-7f75-4f31-8608-0af17386dfb6',
#   'email': 'lindagent@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': ['Maui::Kula'],
#   'climate': []},
#  {'id': 'e728571a-b73c-416b-b76a-fe818abf2b7a',
#   'email': 'udi@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': ['Hawaiʻi::Hilo'],
#   'climate': []},
#  {'id': '18ef1925-d3fe-45f8-8f90-c6db37981026',
#   'email': 'acanavan@kauaiwater.org',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'f0589f24-1434-43df-9042-c71a0d9e6c3c',
#   'email': 'peter.gehring@co.maui.hi.us',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '48a34fb7-bf2c-4297-a807-78df7c10712f',
#   'email': 'gejsen@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'b330e1e1-69b4-4f63-b307-19ed6a137748',
#   'email': 'mguz54@bellsouth.net',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '1b1b9513-f45f-40b4-b338-275b14070152',
#   'email': 'matt.j.medeiros@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'd92368b8-81bf-48b6-ae26-31b9e893be61',
#   'email': 'geraldfisher@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4fad3546-2e6a-44a1-8c03-17990f607196',
#   'email': 'elamj@hawaii.rr.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '36d7ef4a-7c5f-4653-a59f-a605c4e2c562',
#   'email': 'jodi.chew@usda.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Kamilonui'],
#   'moku': [],
#   'climate': []},
#  {'id': '0c5ceb15-5d18-43c2-ad9c-13f0faf17914',
#   'email': 'kolja@usgs.gov',
#   'ahupuaa': ['Oʻahu::Pūpūkea'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '02c794da-2b0d-4fee-8a99-ecf7fcfd8896',
#   'email': 'steven@kae.design',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5c87946c-182f-4d2f-99b8-e05f4f8d6d6a',
#   'email': 'kihalanijoy@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kihalani'],
#   'moku': [],
#   'climate': []},
#  {'id': '9ea2069d-f22b-4c4c-bd7b-b013c080582f',
#   'email': 'matthew.l.baldwin@hawaii.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '098076ce-d50b-434c-9065-871024ea236a',
#   'email': 'bald9@hawaii.edu',
#   'ahupuaa': ['Oʻahu::Waikīkī'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '92b60fee-8844-4834-af35-3462d065a735',
#   'email': 'mch@hawaiiinstituteofrainwater.org',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '897d2f31-91e1-42d6-824e-cef5083f6224',
#   'email': 'nowfield59@gmail.com',
#   'ahupuaa': ['Maui::Wailuku'],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8cfd7f3e-a220-4c37-9148-730d4172df9c',
#   'email': 'p.hennon@comcast.net',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '69981288-3b5f-4f12-bc0c-150ffd75a921',
#   'email': 'nawanachase@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e4601edc-64bd-43ce-8a3a-0f7a5da5419a',
#   'email': 'naaikaneomaui.office@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'b154890d-1939-49eb-b5ee-ace18ebaeece',
#   'email': 'annerosa@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': ['Oʻahu::Kona', 'Hawaiʻi::Kohala'],
#   'climate': []},
#  {'id': 'a2826179-ec27-4cfc-a705-36f61ea15010',
#   'email': 'erica.ta@hawaiicounty.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ee04b30d-8b1d-492d-86d0-49fb624b0a43',
#   'email': 'michelle.visions@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c8bd1ab9-9966-401d-b85a-3412e52b8d1e',
#   'email': 'sesno@hawaii.edu',
#   'ahupuaa': ['Oʻahu::Honolulu'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'b70d68d6-2fa7-4263-8b3b-07d172b22c75',
#   'email': 'danacabatic@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '0eb5850f-2d9b-49d6-a179-06d19e598a39',
#   'email': 'denise.au@hawaiianelectric.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4301cf9c-ec30-4d45-aac3-e6c8e20e3db1',
#   'email': 'watchoffice@hawaiianelectric.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '354d85f0-ffa9-4211-aa79-a546ade8e975',
#   'email': 'ngh1@cornell.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': ['Hawaiʻi::Windward Kohala',
#    'Hawaiʻi::Leeward Kohala',
#    'Hawaiʻi::Hawaiʻi Mauka']},
#  {'id': '580ce0a0-1fa3-4195-b6e1-38db5a7096c0',
#   'email': 'ainahoola@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Kaūmana'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5fc946e5-8402-4c68-b01b-e9266f8b7082',
#   'email': 'geckomaui@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'b45e0852-e849-4eb0-9504-ce0e0dd760f5',
#   'email': 'kyleighk@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'fa8a6528-96b7-43a1-b963-c00a65b08ce5',
#   'email': 'bodhi@maui.net',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kealakekua'],
#   'moku': [],
#   'climate': []},
#  {'id': 'd82564c9-da40-4d61-bb41-1f8de4e77f75',
#   'email': 'photoscooter@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Kealakekua, Kīloa 1'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'bcf71e7d-a7b9-483a-ad8d-70efcbc26acc',
#   'email': 'meglehua@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Wailoa'],
#   'moku': [],
#   'climate': []},
#  {'id': '921c304d-4e77-4a8c-ad45-b577ea74c352',
#   'email': 'robinmkaleiopu@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '7828e035-d40d-4b33-a2d3-de7050bb6517',
#   'email': 'nealdeb@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '88702d59-558f-4768-857d-83193971c9a7',
#   'email': 'lymanperry@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kilauea'],
#   'moku': [],
#   'climate': []},
#  {'id': '0a1ee4e2-e0ba-4a56-950e-43e3e7621191',
#   'email': 'sharrimanpote@hawaiipublicradio.org',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'd5ede5af-afd5-49a6-938d-a6c3a164bd6f',
#   'email': 'jtait@kauaiwater.org',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '0f39c67d-2412-4893-9d64-d7c8032d8918',
#   'email': 'edcbaldwin@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c45ddeea-bf9e-44ed-beee-d891e8577725',
#   'email': 'ghiggin2@uwyo.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Pahole', 'Oʻahu::Kawaihāpai', 'Oʻahu::Honouliuli'],
#   'moku': [],
#   'climate': []},
#  {'id': 'e032bf2c-8030-4133-9950-b23e1b40d99e',
#   'email': 'teruyaf@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '05d56713-4e7d-46a1-ad19-3c41ad28783f',
#   'email': 'dmcole@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'f2527f4d-938b-4467-a994-268bc9010507',
#   'email': 'fleurjasmine@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '23f0655e-f131-4588-ad99-83cedeee2366',
#   'email': 'aamirabdullah@my.unt.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '33636d88-9bfb-484a-95ab-db3d552b18a9',
#   'email': 'aloha.paulb@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '12dcfbe6-d806-40a2-a599-2dc81d581a4d',
#   'email': 'sarah.leinaala@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Waiākea'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '42888a88-468d-48b2-aaa3-f2c1c9bbc12d',
#   'email': 'jennipher.himmelmann@usda.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'bf136a71-7106-46e5-a2db-c91f2950b2e1',
#   'email': 'mrmanuel@ksbe.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '1ebf318d-df2e-4e7b-8941-ae16daa76a17',
#   'email': 'csyamada@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e189c49c-959a-446a-b8a0-9ef0ee7116b6',
#   'email': 'sophlivia@gmail.com',
#   'ahupuaa': ['Oʻahu::Waikīkī'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': ['Oʻahu::Waialua'],
#   'climate': ['Oʻahu::Koʻolau']},
#  {'id': 'f5a05f09-0f35-4c45-9b15-91c131a07a66',
#   'email': 'nthomas1521@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kamakoa'],
#   'moku': [],
#   'climate': []},
#  {'id': 'ed9867e5-8210-4666-838e-5b47314e4e60',
#   'email': 'jaycobmanzano@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a1475f21-ca50-4a3a-b1e5-0dc2a9431320',
#   'email': 'rayjay_hi@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'bedfaa4a-e9f2-4e1b-a3aa-92fd1187a287',
#   'email': 'eparsons@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ba1ca18f-9458-4558-ac86-40b040604ee5',
#   'email': 'eversole@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'cba1b0a9-e8ee-4110-ab34-809313b31008',
#   'email': 'scottspalapa@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '717dc770-23eb-4238-8a31-c860cd92479f',
#   'email': 'tbusch@hawaii.edu',
#   'ahupuaa': ['Oʻahu::Honolulu'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '1fef28a1-0ba0-4b50-b91e-1e55df96d20b',
#   'email': 'leon.peralto@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Koholālele'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e12df3ed-30f7-4d8f-83df-423db2a93abd',
#   'email': 'chu@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '595e58b8-45bd-4cf1-81ed-0e2f6428589a',
#   'email': 'epaxton@usgs.gov',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8b3a8a21-ef1f-4ddc-81aa-769c58589af1',
#   'email': 'kevdavison@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '75a8ceba-2c60-4b88-925d-a3a1b5341884',
#   'email': 'petrop@hawaii.rr.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'b93e975f-9f89-4bb7-9307-3b4c923c1eb4',
#   'email': 'pauldk@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c3851a6a-6e3f-498a-baff-c58f9bf71343',
#   'email': 'mary1959hawaii@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kealakekua'],
#   'moku': [],
#   'climate': []},
#  {'id': '2afb21da-6668-49b3-b5b5-491ec4d1b795',
#   'email': 'hannon1221@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Hakalau'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '133e333d-0c8f-4550-8347-be261ab3c856',
#   'email': 'mark@thestormking.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '00ebe3a6-fba7-4d89-aa0b-315777189853',
#   'email': 'kmeverglade@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'de189b1d-beb1-4639-ac3e-1efe90c610a8',
#   'email': 'sam@nrds.io',
#   'ahupuaa': ['Maui::Haʻikū'],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '681e87c5-2b23-4413-bd24-2bdf22973170',
#   'email': 'kon.matt@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c13ad25c-e604-46ac-8dcb-7e5b32804004',
#   'email': 'mauna_ikena@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '76056f97-abd2-4870-a7ba-7f9efa23aae2',
#   'email': 'sandybarrr@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Honokaia'],
#   'moku': [],
#   'climate': []},
#  {'id': '86f345c3-6cbf-49e4-9684-7b4f07da4873',
#   'email': 'watergirleo@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e16f747e-e605-464a-b76b-198902858708',
#   'email': 'jimbraman@hotmail.com',
#   'ahupuaa': ['Kauaʻi::Kōloa', 'Kauaʻi::Hanalei'],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a47b8419-3b33-49f3-a921-72968806f17f',
#   'email': 'iokimoto@makenagbc.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '98e72bb9-0e73-4985-abb4-934d7f958768',
#   'email': 'connorsaaron@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '23b4cb37-331c-47d5-982d-0625430e57b2',
#   'email': 'katieosterlund@gmail.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a182d283-3acd-4f9d-a87c-7d762be6d374',
#   'email': 'doyleclan11@msn.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a81eca21-70ec-4584-b508-a74b90eaf84a',
#   'email': '4894bb@gmail.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '46c4c2b8-7836-4c65-a6ef-07c4bb6e6461',
#   'email': 'phillipnle@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '27e71b18-9d61-4659-9c82-5c4305ed84d5',
#   'email': 'dpunger1@outlook.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c90bacb4-cdf4-4d50-a012-9f649264b905',
#   'email': 'philippscharles08@gmail.com',
#   'ahupuaa': ['Kauaʻi::Hanapēpē', 'Kauaʻi::Waimea'],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '29a3b3b1-2029-4e6e-9e8e-c6b0e99323bf',
#   'email': 'jj608gb@gmail.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4bc09bc2-bdff-4b08-a3d5-cced34fb58fd',
#   'email': 'earthwindandfaya@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '1aea32e7-e9bd-46b6-8b82-320ec3c5a882',
#   'email': 'jdolapt7@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '9c4bb768-2b87-413e-ab70-98161ebf93da',
#   'email': 'billymanilly@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5f4e2ffa-86b7-4b88-b87a-79871e73e8f9',
#   'email': 'thepeterstone@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Kalaoa 1-5'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'd6548d75-fb5a-4372-a112-95f3c6323972',
#   'email': 'kobayashi559@outlook.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'dad7ade3-04f0-4d7e-a9e6-ff1729ca7818',
#   'email': 'mikeandsuzhawaii@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'f58214fc-aefe-4f17-ad3b-cf607aff1eb0',
#   'email': 'comet986@aol.com',
#   'ahupuaa': ['Hawaiʻi::Keaʻau'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c2682dbf-ff1b-479a-baee-9aa549963181',
#   'email': 'talhelmdan@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Kaʻelepulu'],
#   'moku': [],
#   'climate': []},
#  {'id': 'f567ab1c-83f9-4dd4-ac5f-d04c6c2ce5be',
#   'email': 'micco@kayakkauai.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '1d37724f-7f8f-4fb6-8cc5-4d79b3790ac1',
#   'email': 'everwoodfarm@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kaunā'],
#   'moku': [],
#   'climate': []},
#  {'id': '0037c962-f5e2-48ec-88c1-b330dfdbae28',
#   'email': 'windycreek@outlook.com',
#   'ahupuaa': ['Kauaʻi::Kalihiwai', 'Kauaʻi::Hanalei'],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': ['Kauaʻi::Waileia'],
#   'moku': [],
#   'climate': []},
#  {'id': '163f3dce-d872-42f5-b18e-b2e9ef94bf13',
#   'email': 'paul69hitchcock@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '6c8130ac-4d7e-42e8-b038-a17a7d1c5d7f',
#   'email': 'janetmello333@yahoo.com',
#   'ahupuaa': ['Kauaʻi::Hāʻena'],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '37dd56d0-4ebb-4954-bcb7-86c07aa4180e',
#   'email': 'maunakilauea@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': ['Hawaiʻi::Kaʻū'],
#   'climate': []},
#  {'id': '54f3e79c-76c4-4704-8b89-91d74858fab1',
#   'email': 'pamelaknight808@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e278b860-e9ca-47c9-bdf7-619935e580cb',
#   'email': 'palos@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '614a2d2e-bd2c-4a16-b1d1-8f05e251e7b4',
#   'email': 'alohamees@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'd6e56e29-4a30-4329-acb5-8738d41bae0a',
#   'email': 'ken.slauson+uh@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Nienie'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8dd804f3-a44e-473b-9037-833070a08523',
#   'email': 'connectsccs@outlook.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '6871b732-7329-485b-bd11-48950269c9a7',
#   'email': 'ftlsun@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '392c585c-c6da-483c-b392-f88feeb6a114',
#   'email': 'klee@hbws.org',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '938436cb-5c8c-43b8-bca3-16604beab206',
#   'email': 'reidmahoney2011@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'fb63d963-f6cd-4f2b-89ff-c68762be77ec',
#   'email': 'leeeiford@comcast.net',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'a9dce567-ddd8-4113-bca0-951a216cda28',
#   'email': 'skipstahr@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '585aeb52-fc7f-44d8-a9a9-181b895c86f9',
#   'email': 'cat_trax@juno.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '1c46f97c-dac5-4ec6-aebe-77d38540608d',
#   'email': 'cardwelj@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '0216102b-ffc2-4c2c-8d86-1f44003ebae3',
#   'email': 'ron.whitmore@altago.com',
#   'ahupuaa': ['Oʻahu::Honouliuli'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '9455ce87-0f90-4097-aeb5-4f9d1947d7fa',
#   'email': 'myriadfisheries@gmail.com',
#   'ahupuaa': ['Hawaiʻi::ʻOʻoma 1', 'Hawaiʻi::Kamāʻoa, Puʻuʻeo, Ke'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '0ddacb35-7fdd-4eef-ba0e-e121eb2683eb',
#   'email': 'michaeljohnepp@gmail.com',
#   'ahupuaa': ['Oʻahu::Hauʻula'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '952186b8-a0ec-4aae-a259-e7f471e749a5',
#   'email': 'jjkennedy@usgs.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '85176915-b66b-487d-95e4-3ecf88ac6888',
#   'email': 'sharongralapp@hotmail.com',
#   'ahupuaa': ['Hawaiʻi::Makuʻu, Pōpōkī, Hālo'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '70ac82a9-e1bc-4cc7-bfb8-ce32ceaf62b3',
#   'email': 'susanproctor77@icloud.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '0eb22fcb-2979-47bb-a755-3bfa371eb8ec',
#   'email': 'ruth3@me.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': ['Hawaiʻi::Kona'],
#   'climate': []},
#  {'id': 'bfd9d49a-59f1-43e9-836a-889a908b0ff8',
#   'email': 'laurynrh@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': ['Oʻahu::Kona'],
#   'climate': []},
#  {'id': 'fd88ad51-81cd-47a9-b7b3-a0b32f0aa51f',
#   'email': 'hamakuab@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '992d3e88-a596-4639-b755-e83d13a2987a',
#   'email': 'mleung@ucar.edu',
#   'ahupuaa': ['Hawaiʻi::Puʻuwaʻawaʻa'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': ['Hawaiʻi::Kona'],
#   'climate': []},
#  {'id': 'ff6feb30-ccf5-4d3f-9370-4c22edcbfa1e',
#   'email': 'bnlkmtka@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '032aac0f-c1a0-445b-9729-9e350430ebea',
#   'email': 'christinelindseylee@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Keʻei 2', 'Hawaiʻi::Keʻei 1'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kealakekua'],
#   'moku': [],
#   'climate': []},
#  {'id': '83fdee74-d8ee-480e-aef2-8691a37408db',
#   'email': 'cadippery@msn.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Waiʻaha'],
#   'moku': [],
#   'climate': []},
#  {'id': 'dad352d5-ad94-4a1a-909b-3823002c4004',
#   'email': 'tigermax123@aim.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '2a1effec-85de-4bcb-baea-b17e0aa6422a',
#   'email': 'todd123@hawaii.rr.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ce3f9540-14ad-45bb-8641-d9283d7bdec2',
#   'email': 'nsfrider8@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '901ed4f2-3b15-460b-adb3-2164a8910631',
#   'email': 'davelambrecht@icloud.com',
#   'ahupuaa': ['Hawaiʻi::Hāwī'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': ['Hawaiʻi::Windward Kohala']},
#  {'id': '6bc0bf73-22d7-4699-ac94-110956d99e55',
#   'email': 'jeff.jjones@sbcglobal.net',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '162c913d-ed4f-47d8-bfd3-32730251c486',
#   'email': 'jenspam@outlook.com',
#   'ahupuaa': ['Oʻahu::Maunalua'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'b0c3b972-f7d0-487e-b844-6aa855bc0c9c',
#   'email': 'tina.m.ahn@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'd5e1f849-8650-4a14-bd22-6a5d57f403ce',
#   'email': 'alakaihugh@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Kalopā'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '91864b3a-581a-4eb5-a73c-e95290cc0122',
#   'email': 'liana.white@k12.hi.us',
#   'ahupuaa': ['Hawaiʻi::Keʻei 1'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8a458510-68d4-44e4-b4d6-153f046f0a4c',
#   'email': 'jstrong53402@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kīlau'],
#   'moku': [],
#   'climate': []},
#  {'id': '000703b3-3e96-4d80-b11e-7a86f219cae8',
#   'email': 'ajroy1@gmail.com',
#   'ahupuaa': ['Hawaiʻi::ʻŌlaʻa'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'bedae079-2268-4f30-87a9-f258c48618ed',
#   'email': 'brian_hudson@msn.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Keāhole'],
#   'moku': [],
#   'climate': []},
#  {'id': '2ced72bf-6a88-4dc0-be2c-0f8451761ebe',
#   'email': 'higa.alison@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Wailoa'],
#   'moku': [],
#   'climate': []},
#  {'id': 'f5fb2f1c-01e1-416c-b37f-beba8c0ed3ae',
#   'email': 'Anotherpaularnold@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Nānāwale'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'faa28c49-955c-4055-bef1-d5a4cb083ad2',
#   'email': 'julesbrianhawaii@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '49c21aa1-a7b0-4a4f-9726-fc62f6bfa07e',
#   'email': 'cecilwilson@pobox.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8aace123-86ef-40ef-88a1-065753e9c6e9',
#   'email': 'chessinenugent@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'dd7e28e3-366f-48bb-a280-6c91ed0d476f',
#   'email': 'wargorich@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Waikā', 'Hawaiʻi::Kahuā 2', 'Hawaiʻi::Kawaihae 1'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '8b8f31c9-6904-47d4-9702-bd9604ba1a74',
#   'email': 'jwoicik@outlook.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e55dbc34-85f9-457f-87bb-73bf54254c1e',
#   'email': 'hayley.cook@honolulu.gov',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5965ff04-85cd-4a8c-b4b3-7570695ba29a',
#   'email': 'blurb-sledge7f@icloud.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': ['Hawaiʻi::Kilauea'],
#   'moku': [],
#   'climate': []},
#  {'id': '9d0b251c-2d3e-4c56-a86f-0a6e1b93e408',
#   'email': 'rpap@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4960a9b0-e1d3-45b3-988a-90512a76f05e',
#   'email': 'mckenna.s.allen@hawaii.gov',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '40940da7-7c1b-4813-a61f-d5b67dc10690',
#   'email': 'kfay@tnc.org',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '51b666f4-096e-4208-8461-abf5c61a86b0',
#   'email': 'lucindaluna@ymail.com',
#   'ahupuaa': ['Hawaiʻi::Kapulena'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'aa559459-7697-4069-9b9a-60706a5ccd33',
#   'email': 'erica.gallerani@tnc.org',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '32f7e559-2e54-4fd8-9cc0-1b823611ceb9',
#   'email': 'okimotod@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Ala Wai'],
#   'moku': [],
#   'climate': []},
#  {'id': '6c166b6b-6fdd-441d-95f7-53448fdbfac1',
#   'email': 'francescatenebra@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': ['Hawaiʻi::Hilo']},
#  {'id': '4d25a1c9-1665-4e6c-88a3-85f983829902',
#   'email': 'mizumi@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '832d2bad-008b-47e3-9381-7b0a40f3232c',
#   'email': 'adam.m.williams@hawaii.gov',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '69d204eb-5113-42df-b07b-bfb3720bb2ed',
#   'email': 'cmpinpin@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Keaʻau'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '548336e1-bd37-482f-94c5-9de62a6af204',
#   'email': 'david.dunton@gmail.com',
#   'ahupuaa': ['Hawaiʻi::ʻŌlaʻa'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'bef9b13c-5aa7-4d32-be67-6427f35ef633',
#   'email': 'kihne@msn.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ae9fa95e-4885-448d-bb51-050aa144b07d',
#   'email': 'maenettmedia@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Puapuaʻa 2'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '12b3520b-a59f-4298-8717-45616b22d516',
#   'email': 'pianta1@hotmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '880643c3-96d7-4c5b-8015-62a1dde36d1f',
#   'email': 'loriannaherrmann@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': ['Oʻahu::Kona'],
#   'climate': []},
#  {'id': 'fab8188c-8ea5-4f5b-ae5a-8eef377d5796',
#   'email': 'davedouglas3@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Opihilala'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'fd410ca7-6ed0-4433-bb61-905dad866e6e',
#   'email': 'cconn3@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Opihilala'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '773b7420-6d79-4b8b-b985-7fef0e85f57f',
#   'email': 'baddobro@gmail.com',
#   'ahupuaa': ['Hawaiʻi::Kalopā'],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '4ebd4fc8-b874-4411-8595-91792eccf235',
#   'email': 'mamorrissey@comcast.net',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ed6cd88a-b655-42ba-a340-05e01c267aa8',
#   'email': 'dmforuhpa@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'd91f5adb-80fc-45d1-8a1b-bf6ac1eabb85',
#   'email': 'liliawd@hawaii.edh',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': ['Maui::Hāmākualoa'],
#   'climate': []},
#  {'id': '5967e99c-f776-4f4b-bdb2-75d0f914a00e',
#   'email': 'liliawd@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': ['Maui::Hāmākualoa'],
#   'climate': []},
#  {'id': 'ce5bbb23-d41a-4c36-ae31-10e45bd457c9',
#   'email': 'liliadavis2020@gmail.com',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': ['Maui::Hāmākualoa'],
#   'climate': []},
#  {'id': '9bf4a6c7-20ee-4236-9c9b-957db31bf57f',
#   'email': 'moy.deb@gmail.com',
#   'ahupuaa': ['Maui::Makawao'],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '6dcb6b9b-1433-45fe-a7e6-6e6a1d59249e',
#   'email': 'shrickards@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '9fd49dea-350f-4f19-a461-28edc3777381',
#   'email': 'linda.l.hill10@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '07c3c68b-1363-48d8-bd2e-2718e7781245',
#   'email': 'kgrabar@hawaii.edu',
#   'ahupuaa': ['Oʻahu::Maunalua'],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'dafef242-36d1-4632-a462-eb6eac432881',
#   'email': 'julia@atchawaii.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '30b5ce41-cafc-41bd-b0e3-c78ef56dbff1',
#   'email': 'Jonathan.Case-1@nasa.gov',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'f94d83af-e8b2-4929-b687-a58a0b40d81a',
#   'email': 'suemings@mac.com',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '55767ad4-11f4-420b-81d4-f66f1492fbbd',
#   'email': 'commreshawaii@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '3d6cb5b9-da31-4628-9631-9e681997c54f',
#   'email': 'srivatsavaadithya@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '3d833bdf-6d52-4601-bca1-8e8988d8446d',
#   'email': 'dangelo.igor@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '97d37349-0260-4ced-a0bf-115db0fe1385',
#   'email': 'ryanscottg@yahoo.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e197acd3-ffb0-4ca9-b14b-afd4a72cd43b',
#   'email': 'rdfusch@owu.edu',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '5777aa53-30f7-4e61-b630-e435f9cf8453',
#   'email': 'riley.thompson@tnc.org',
#   'ahupuaa': [],
#   'island': ['Kauaʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '54b775e7-d999-45ec-8c11-8cf3020ca952',
#   'email': 'irishroy@gmail.com',
#   'ahupuaa': [],
#   'island': ['Oʻahu', 'Statewide'],
#   'watershed': ['Oʻahu::Nuʻuanu'],
#   'moku': [],
#   'climate': []},
#  {'id': '782c55c9-5d5c-4d68-af4d-7b751f3b6051',
#   'email': 'cbgb2112@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'e2b98189-e5da-4ea3-a10c-9fe1a6e80867',
#   'email': 'najitaems@gmail.com',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'c2d39984-f439-4e58-93b4-b70d64241aa4',
#   'email': 'eloise_young@alum.mit.edu',
#   'ahupuaa': [],
#   'island': ['Maui', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': '683299d3-9893-46c6-b62b-46c5f2ffff06',
#   'email': 'peterlasich@gmail.com',
#   'ahupuaa': [],
#   'island': ['Hawaiʻi', 'Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []},
#  {'id': 'ba2d599e-258d-4850-a6a8-748b618a802a',
#   'email': 'downing4@hawaii.edu',
#   'ahupuaa': [],
#   'island': ['Statewide'],
#   'watershed': [],
#   'moku': [],
#   'climate': []}]

# %%
url = f"https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/98f9c789-5ac5-427c-9ad8-e1f9076e8b3c/unsubscribe"
res = requests.patch(url, headers = headers)
res.raise_for_status()

# %%
report_email_content_text = "This is a test message\nThis will be populated with your climate report content"
report_email_content_html = "<div><p>This is a test message<br/>This will be populated with your climate report content</p><div style='color:purple;font-weight:bold;font-size:24px;'>Most email clients will use HTML content and this can be formatted however you want</div></div>"
body = {
  "text": report_email_content_text,
  "html": report_email_content_html
}
url = f"https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/{userID}/email"
res = requests.post(url, json = body, headers = headers)
res.raise_for_status()
print("User has been sent an email")
print(res.json())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       7 url = f"https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/{userID}/email"
#       8 res = requests.post(url, json = body, headers = headers)
# ----> 9 res.raise_for_status()
#      10 print("User has been sent an email")
#      11 print(res.json())
#
# File /opt/anaconda3/envs/mesonetenv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/None/email

# %%
url = "https://api.hcdp.ikewai.org/mesonet/climate_report/subscriptions"
res = requests.get(url, headers = headers)
res.raise_for_status()
print("Shows an array of all subscriptions (admin only)")
subs = res.json()
print(subs)
emails = [sub["email"] for sub in subs]
print(emails)
# Out:
# Shows an array of all subscriptions (admin only)
# [{'id': 'acc70452-5237-4c72-be7b-b552a2454fc2', 'email': 'cherryle.heu@gmail.com', 'ahupuaa': ['Oʻahu::Kamananui'], 'island': ['Oʻahu'], 'watershed': [], 'moku': []}, {'id': '98f9c789-5ac5-427c-9ad8-e1f9076e8b3c', 'email': 'cherryle@hawaii.edu', 'ahupuaa': ['Kauaʻi::Haʻikū'], 'island': ['Statewide', 'Oʻahu', 'Kauaʻi'], 'watershed': ['Oʻahu::Kamiloiki'], 'moku': ['Oʻahu::Waiʻanae', 'Kauaʻi::Nāpali']}, {'id': 'e900753f-8922-46ab-9064-6438de84446c', 'email': 'cherrylee983@gmail.com', 'ahupuaa': [], 'island': ['kauai'], 'watershed': [], 'moku': []}, {'id': 'dc982fae-ca29-43be-9b06-e01a4c362f8a', 'email': 'ksanfili@hawaii.edu', 'ahupuaa': [], 'island': ['Statewide'], 'watershed': [], 'moku': []}, {'id': '96ad0684-d2ed-45d0-b71e-aff98d38e195', 'email': 'akuegler@hawaii.edu', 'ahupuaa': [], 'island': ['Statewide'], 'watershed': [], 'moku': []}, {'id': 'd7620d60-53aa-48d7-a3d0-47e76db9d468', 'email': 'djford@hawaii.edu', 'ahupuaa': [], 'island': ['Statewide'], 'watershed': [], 'moku': []}, {'id': '90ebe680-efd8-4b64-a4e4-7f8061d99f37', 'email': 'mcleanj@hawaii.edu', 'ahupuaa': ['Hawaiʻi::Keaʻau'], 'island': ['Statewide', 'Hawaiʻi'], 'watershed': [], 'moku': []}, {'id': 'bb0a4eac-e730-4509-ae31-0abfcbe6af6b', 'email': 'abbyf@hawaii.edu', 'ahupuaa': [], 'island': ['Statewide'], 'watershed': [], 'moku': []}, {'id': '5a48288f-f179-4acd-af78-058cc0505d52', 'email': 'vmhyomai@hawaii.edu', 'ahupuaa': [], 'island': ['Statewide'], 'watershed': [], 'moku': []}, {'id': '26cba191-e8f4-4066-8bd6-85aea4792470', 'email': 'brian.brettschneider@noaa.gov', 'ahupuaa': [], 'island': ['Oʻahu', 'Statewide'], 'watershed': [], 'moku': []}, {'id': 'c5392660-b100-4810-a105-e141744015ab', 'email': 'brandon.bukunt@noaa.gov', 'ahupuaa': [], 'island': ['Statewide'], 'watershed': [], 'moku': []}]
# ['cherryle.heu@gmail.com', 'cherryle@hawaii.edu', 'cherrylee983@gmail.com', 'ksanfili@hawaii.edu', 'akuegler@hawaii.edu', 'djford@hawaii.edu', 'mcleanj@hawaii.edu', 'abbyf@hawaii.edu', 'vmhyomai@hawaii.edu', 'brian.brettschneider@noaa.gov', 'brandon.bukunt@noaa.gov']

# %%
body = {
    "email": "cherryle@hawaii.edu",
    "county": ["honolulu, maui"],
    "moku": ["wahiawa"]
}

url = "https://api.hcdp.ikewai.org/mesonet/climate_report/subscribe"
res = requests.post(url, json = body, headers = headers)
res.raise_for_status()
print("User subscribed")
# Out:
# User subscribed

# %%
#Get existing subscription info. If new subscription, userID is None. 
params = {
  "email": "cherryle@hawaii.edu"
}
url = "https://api.hcdp.ikewai.org/mesonet/climate_report/email_lookup"
res = requests.get(url, json = body, params = params, headers = headers)
res.raise_for_status()
data = res.json()
userID = data["userID"]

url = f"https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/{userID}"
res = requests.get(url, headers = headers)
json = res.json()

new_body = {
    "email": "cherryle@hawaii.edu",
    "county": ["hawaii"],
    "moku": ["kohala"]
}

LIST_FIELDS = ["county", "moku", "ahupuaa", "watershed"]

updated_body = {"email": json["email"]}

for f in LIST_FIELDS:
    old_vals = json.get(f, []) 
    new_vals = new_body.get(f, []) 
    updated_body[f] = list(dict.fromkeys(old_vals + new_vals))

updated_body
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/anaconda3/envs/mesonetenv/lib/python3.11/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/anaconda3/envs/mesonetenv/lib/python3.11/site-packages/simplejson/__init__.py:514, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     510 if (cls is None and encoding is None and object_hook is None and
#     511         parse_int is None and parse_float is None and
#     512         parse_constant is None and object_pairs_hook is None
#     513         and not use_decimal and not allow_nan and not kw):
# --> 514     return _default_decoder.decode(s)
#     515 if cls is None:
#
# File /opt/anaconda3/envs/mesonetenv/lib/python3.11/site-packages/simplejson/decoder.py:386, in JSONDecoder.decode(self, s, _w, _PY3)
#     385     s = str(s, self.encoding)
# --> 386 obj, end = self.raw_decode(s)
#     387 end = _w(s, end).end()
#
# File /opt/anaconda3/envs/mesonetenv/lib/python3.11/site-packages/simplejson/decoder.py:416, in JSONDecoder.raw_decode(self, s, idx, _w, _PY3)
#     415         idx += 3
# --> 416 return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[2], line 13
#      11 url = f"https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/{userID}"
#      12 res = requests.get(url, headers = headers)
# ---> 13 json = res.json()
#      15 new_body = {
#      16     "email": "cherryle@hawaii.edu",
#      17     "county": ["hawaii"],
#      18     "moku": ["kohala"]
#      19 }
#      21 LIST_FIELDS = ["county", "moku", "ahupuaa", "watershed"]
#
# File /opt/anaconda3/envs/mesonetenv/lib/python3.11/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
url = f"https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/{userID}"
res = requests.patch(url, json = updated_body, headers = headers)
res.raise_for_status()
print("Subscription updated")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 url = f"https://api.hcdp.ikewai.org/mesonet/climate_report/subscription/{userID}"
#       2 res = requests.patch(url, json = updated_body, headers = headers)
#       3 res.raise_for_status()
#
# NameError: name 'userID' is not defined
