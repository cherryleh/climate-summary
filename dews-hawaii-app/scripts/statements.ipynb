# %%
import os
import re
import glob
import argparse
import requests
import pandas as pd
import numpy as np
import geopandas as gpd
import rasterio
from urllib.parse import urlencode
from datetime import datetime
from rasterstats import zonal_stats

# %%
import pytz
from dateutil import parser

hst = pytz.timezone('Pacific/Honolulu')
parser.parse("2026-02").astimezone(hst)
# Out:
# datetime.datetime(2026, 2, 23, 0, 0, tzinfo=<DstTzInfo 'Pacific/Honolulu' HST-1 day, 14:00:00 STD>)

# %%
"Statewide received 2.0 inches of rainfall statewide — 3.2 inches (62%) below the August average, marking the driest August in the last 30 years."

# %%
rain_avg = 1
rain_anom = -2
rain_anom_perc = -62
rank = 1
def get_drought_statement(rain_avg, rain_anom, rain_anom_perc):
    if rain_anom_perc < -50:
        return f"Statewide received {rain_avg} inches of rainfall statewide — {abs(rain_anom)} inches ({abs(rain_anom_perc)}%) below the average, marking the driest month in the last 30 years."
    else:
        return f"Statewide received {rain_avg} inches of rainfall statewide — {abs(rain_anom)} inches ({abs(rain_anom_perc)}%) below the average."
